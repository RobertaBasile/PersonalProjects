# %% [markdown]
# Analisi dataset Avian Biodiversity Database:'birds.csv'
#
# Credits: https://www.kaggle.com/datasets/shreyasur965/avian-biodiversity-database

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('birds.csv')

# %%
# Visualizzare i nomi di tutte le colonne
print(data.columns)
# Out:
# Index(['name', 'species', 'family', 'habitat', 'place_of_found', 'diet',
#        'description', 'weight_kg', 'image'],
#       dtype='object')

# %%
# Visualizzare le prime righe del dataset
print(data.head())
# Out:
#           name                   species        family  \
# 0   Bald Eagle  Haliaeetus leucocephalus  Accipitridae
# 1      Peacock            Pavo cristatus   Phasianidae
# 2     Hornbill               Bucerotidae   Bucerotidae
# 3  Hummingbird               Trochilidae   Trochilidae
# 4      Penguin              Spheniscidae  Spheniscidae
#
#                             habitat    place_of_found                diet  \
# 0        Forests, Coasts, and Lakes     North America           Carnivore
# 1            Forests and Grasslands             India            Omnivore
# 2             Forests and Woodlands      Africa, Asia            Omnivore
# 3  Tropical and Subtropical Regions          Americas  Nectar and Insects
# 4                        Antarctica  Antarctic Region           Carnivore
#
#                                          description  weight_kg  \
# 0  The bald eagle is a powerful bird of prey know...     6.3000
# ...

# %%
display(data)
# Out:
#                       name                   species             family  \
# 0               Bald Eagle  Haliaeetus leucocephalus       Accipitridae
# 1                  Peacock            Pavo cristatus        Phasianidae
# 2                 Hornbill               Bucerotidae        Bucerotidae
# 3              Hummingbird               Trochilidae        Trochilidae
# 4                  Penguin              Spheniscidae       Spheniscidae
# 5                   Toucan              Ramphastidae       Ramphastidae
# 6                Albatross               Diomedeidae        Diomedeidae
# 7                 Flamingo          Phoenicopteridae   Phoenicopteridae
# 8                  Ostrich          Struthio camelus      Struthionidae
# 9                Snowy Owl           Bubo scandiacus          Strigidae
# 10                Toucanet            Aulacorhynchus       Ramphastidae
# 11              Kingfisher               Alcedinidae        Alcedinidae
# ...
